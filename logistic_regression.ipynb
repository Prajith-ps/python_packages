# %%
import pandas as pd
df= pd.read_csv('hr_comma_sep.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Department']=le.fit_transform(df['Department'])
df['salary']=le.fit_transform(df['salary'])
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  Department  salary
# 0                          0           7       1
# 1                          0           7       2
# 2                          0           7       2
# 3                          0           7       1
# 4                          0           7       1
# ...                      ...         ...     ...
# 14994                      0           8       1
# 14995                      0           8       1
# 14996                      0           8       1
# 14997                      0           8       1
# 14998                      0           8       1
#
# [14999 rows x 10 columns]

# %%
x=df.drop('salary',axis=1)
x.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7

# %%
y=df['salary']
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    1
# 4    1
# Name: salary, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
X_train.shape
# Out:
# (10499, 9)

# %%
X_test.shape
# Out:
# (4500, 9)

# %%
y_train.shape
# Out:
# (10499,)

# %%
y_test.shape
# Out:
# (4500,)

# %%
from sklearn.preprocessing import StandardScaler
sl=StandardScaler()
X_train=sl.fit_transform(X_train)
X_train
# Out:
# array([[-0.33839336, -1.26804016,  0.16074055, ..., -0.55494201,
#         -0.14965797, -1.00355184],
#        [ 0.75196516,  1.12959882, -0.65571566, ..., -0.55494201,
#         -0.14965797,  0.39244561],
#        [-1.87297202, -0.33237616,  0.16074055, ..., -0.55494201,
#         -0.14965797,  1.09044433],
#        ...,
#        [-0.33839336,  0.48632983, -1.47217187, ..., -0.55494201,
#          6.68190288, -0.65455247],
#        [ 0.06544313,  0.07697683, -0.65571566, ..., -0.55494201,
#         -0.14965797,  0.04344625],
#        [-1.63067013,  0.25241383,  0.16074055, ..., -0.55494201,
#         -0.14965797,  0.04344625]])

# %%
X_test=sl.fit_transform(X_test)
X_test
# Out:
# array([[ 0.43603156,  0.26592328,  0.15763383, ..., -0.56845427,
#         -0.14204517,  0.74435335],
#        [ 1.31280625,  1.08211575,  0.15763383, ..., -0.56845427,
#         -0.14204517,  0.74435335],
#        [-0.95883725, -1.48306059, -1.44180753, ...,  1.75915647,
#         -0.14204517, -2.03683197],
#        ...,
#        [-1.15810422, -1.36646166,  0.15763383, ..., -0.56845427,
#          7.04001404, -0.29859115],
#        [ 0.43603156,  1.19871468, -0.64208685, ..., -0.56845427,
#         -0.14204517,  0.39670518],
#        [ 0.8744189 ,  0.03272543, -0.64208685, ..., -0.56845427,
#         -0.14204517,  1.09200151]])

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 2, 2, 1])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# 2       2
# 3       1
# 4       1

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[   0,  183,  183],
#        [   0, 1633,  597],
#        [   0, 1289,  615]], dtype=int64)

# %%
new_data=[[0.38,0.53,2,157,3,0,1,0,7]]
y_pred=lr.predict(new_data)
y_pred
# Out:
# array([0])
